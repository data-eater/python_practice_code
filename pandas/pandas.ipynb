# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv')
schema_df=pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         79 non-null     object
#  1   qname       79 non-null     object
#  2   question    79 non-null     object
#  3   force_resp  66 non-null     object
#  4   type        79 non-null     object
#  5   selector    79 non-null     object
# dtypes: object(6)
# memory usage: 3.8+ KB

# %%
df.shape
# Out:
# (73268, 79)

# %%
schema_df[['qname','question']]
# Out:
#           qname                                           question
# 0            S0  <div><span style="font-size:19px;"><strong>Hel...
# 1      MetaInfo                                  Browser Meta Info
# 2            S1  <span style="font-size:22px; font-family: aria...
# 3    MainBranch  Which of the following options best describes ...
# 4    Employment  Which of the following best describes your cur...
# ..          ...                                                ...
# 74  Frequency_2  Interacting with people outside of your immedi...
# 75  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  TrueFalse_2  Do you use learning resources provided by your...
# 78  TrueFalse_3  Does your employer give you time to learn new ...
#
# [79 rows x 2 columns]

# %%
df.head(20)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# ...

# %%
df.tail(20)
# Out:
#        ResponseId                                         MainBranch  \
# 73248       73249                     I am a developer by profession
# 73249       73250                              I am learning to code
# 73250       73251                     I am a developer by profession
# 73251       73252                     I am a developer by profession
# 73252       73253                              I am learning to code
# 73253       73254                     I am a developer by profession
# 73254       73255  I am not primarily a developer, but I write co...
# 73255       73256                     I am a developer by profession
# 73256       73257                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# ...

# %%
df['Country']
# Out:
# 0                                                      NaN
# 1                                                   Canada
# 2        United Kingdom of Great Britain and Northern I...
# 3                                                   Israel
# 4                                 United States of America
#                                ...
# 73263                                              Nigeria
# 73264                             United States of America
# 73265                             United States of America
# 73266    United Kingdom of Great Britain and Northern I...
# 73267                                               Canada
# Name: Country, Length: 73268, dtype: object

# %%
df[['Country','Employment']]
# Out:
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                                               Employment
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.iloc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
df.loc[1,['Age','Gender','Country','Employment']]
# Out:
# Age                           NaN
# Gender                        NaN
# Country                    Canada
# Employment    Employed, full-time
# Name: 1, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.loc[0:5,'Age':'Ethnicity']
# Out:
#                Age                  Gender                   Trans  \
# 0              NaN                     NaN                     NaN
# 1              NaN                     NaN                     NaN
# 2  25-34 years old                     Man                      No
# 3  35-44 years old                     Man                      No
# 4  25-34 years old                     NaN                     NaN
# 5  25-34 years old  Or, in your own words:  Or, in your own words:
#
#                   Sexuality               Ethnicity
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                  Bisexual                   White
# 3   Straight / Heterosexual                   White
# 4                       NaN                     NaN
# 5  Prefer to self-describe:  Or, in your own words:

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 180, dtype: int64

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.loc[0:10,'Country']
# Out:
# 0                                                   NaN
# 1                                                Canada
# 2     United Kingdom of Great Britain and Northern I...
# 3                                                Israel
# 4                              United States of America
# 5                                               Germany
# 6                                                 India
# 7                                                 India
# 8                                           Netherlands
# 9                                               Croatia
# 10    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
df.set_index('Country',inplace=True)

# %%
df.loc['Israel']
# Out:
#          ResponseId                                         MainBranch  \
# Country
# Israel            4                     I am a developer by profession
# Israel           25                     I am a developer by profession
# Israel           28                     I am a developer by profession
# Israel           34  I am not primarily a developer, but I write co...
# Israel           36  I am not primarily a developer, but I write co...
# ...             ...                                                ...
# Israel        72831                     I am a developer by profession
# Israel        72962                     I am a developer by profession
# Israel        73002                     I am a developer by profession
# Israel        73012                     I am a developer by profession
# Israel        73239                     I am a developer by profession
#
#                                                 Employment  \
# Country
# ...

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df.reset_index(inplace=True)

# %%
schema_df.set_index('qname',inplace=True)

# %%
schema_df.loc['Employment','question']
# Out:
# 'Which of the following best describes your current employment status?'

# %%
schema_df.sort_index(inplace=True)

# %%
filt=df['Country']=='Pakistan'

# %%
print(type(filt))
print(filt)
print(df.loc[filt, 'RemoteWork'].value_counts())
# Out:
# <class 'pandas.core.series.Series'>
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73263    False
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# Name: Country, Length: 73268, dtype: bool
# RemoteWork
# Full in-person                          209
# Hybrid (some remote, some in-person)    207
# Fully remote                            162
# Name: count, dtype: int64

# %%
filt2=(df['Country']=='Pakistan') & (df['RemoteWork'] == 'Fully remote')
# df[['Country','RemoteWork']]

# %%
df.loc[filt2]
# Out:
#         Country  ResponseId  \
# 916    Pakistan         917
# 1390   Pakistan        1391
# 3585   Pakistan        3586
# 4354   Pakistan        4355
# 4727   Pakistan        4728
# ...         ...         ...
# 71904  Pakistan       71905
# 71984  Pakistan       71985
# 72000  Pakistan       72001
# 72868  Pakistan       72869
# 72908  Pakistan       72909
#
#                                               MainBranch  \
# 916                       I am a developer by profession
# 1390                      I am a developer by profession
# 3585                               I am learning to code
# 4354                      I am a developer by profession
# 4727                      I am a developer by profession
# ...                                                  ...
# 71904                     I am a developer by profession
# 71984  I am not primarily a developer, but I write co...
# 72000                     I am a developer by profession
# ...

# %%
df.loc[((~filt2) & (df['Country']=='Pakistan'))]
# Out:
#         Country  ResponseId  \
# 1198   Pakistan        1199
# 2917   Pakistan        2918
# 3044   Pakistan        3045
# 3509   Pakistan        3510
# 3553   Pakistan        3554
# ...         ...         ...
# 71774  Pakistan       71775
# 71798  Pakistan       71799
# 72824  Pakistan       72825
# 72937  Pakistan       72938
# 73028  Pakistan       73029
#
#                                               MainBranch  \
# 1198                               I am learning to code
# 2917                      I am a developer by profession
# 3044                      I am a developer by profession
# 3509                      I am a developer by profession
# 3553                      I am a developer by profession
# ...                                                  ...
# 71774                              I am learning to code
# 71798  I used to be a developer by profession, but no...
# 72824                     I am a developer by profession
# ...

# %%
common_languages=['Python','JavaScript','C++']
countries=['Pakistan','Turkey']
filt3=(df['ConvertedCompYearly'] > 10000) & (df['Country'].isin(countries)) & (df['LanguageHaveWorkedWith'].str.contains('Python'))
df.loc[filt3,'LanguageHaveWorkedWith']
# Out:
# 99        C;C++;HTML/CSS;Java;JavaScript;MATLAB;Python;SQL
# 1301              Assembly;C;C++;Go;JavaScript;Python;Rust
# 1390     Assembly;Bash/Shell;C;C++;Dart;Go;HTML/CSS;Jav...
# 2495     Bash/Shell;C;C#;Dart;Elixir;Erlang;Java;JavaSc...
# 3830                               HTML/CSS;PHP;Python;SQL
#                                ...
# 71656                HTML/CSS;JavaScript;Python;TypeScript
# 71707       Assembly;C;C#;C++;COBOL;Fortran;Python;SQL;VBA
# 72386       HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 72824             Dart;JavaScript;Kotlin;Python;TypeScript
# 72908                               JavaScript;Python;Rust
# Name: LanguageHaveWorkedWith, Length: 172, dtype: object

# %%
test_df=(df.loc[filt,['Country','Employment']]).iloc[0:10]

# %%
test_df.columns=['Country Name','Employment Status']
test_df.columns=test_df.columns.str.replace(' ','_')
test_df
# Out:
#      Country_Name                                  Employment_Status
# 916      Pakistan                                Employed, full-time
# 1198     Pakistan                                 Student, full-time
# 1390     Pakistan                                Employed, full-time
# 2917     Pakistan                                Employed, full-time
# 3044     Pakistan                                Employed, full-time
# 3509     Pakistan  Employed, full-time;Independent contractor, fr...
# 3553     Pakistan                                Employed, full-time
# 3585     Pakistan  Student, part-time;Independent contractor, fre...
# 3598     Pakistan                                Employed, full-time
# 3694     Pakistan                                Employed, full-time

# %%
test_df.rename(columns={'Country_Name':'Country'},inplace=True)
test_df
# Out:
#        Country                                  Employment_Status
# 916   Pakistan                                Employed, full-time
# 1198  Pakistan                                 Student, full-time
# 1390  Pakistan                                Employed, full-time
# 2917  Pakistan                                Employed, full-time
# 3044  Pakistan                                Employed, full-time
# 3509  Pakistan  Employed, full-time;Independent contractor, fr...
# 3553  Pakistan                                Employed, full-time
# 3585  Pakistan  Student, part-time;Independent contractor, fre...
# 3598  Pakistan                                Employed, full-time
# 3694  Pakistan                                Employed, full-time

# %%
def remove_unnecessary_words(word:str):
    return word.split(',')[0]

test_df['Employment_Status']=test_df['Employment_Status'].apply(lambda x:x.split(',')[0])

# %%
test_df.apply(len,axis=0)
# Out:
# Country              10
# Employment_Status    10
# dtype: int64

# %%
test_df['Employment_Status'].replace({'Student':'Not-Employed'})
# Out:
# 916         Employed
# 1198    Not-Employed
# 1390        Employed
# 2917        Employed
# 3044        Employed
# 3509        Employed
# 3553        Employed
# 3585    Not-Employed
# 3598        Employed
# 3694        Employed
# Name: Employment_Status, dtype: object

# %%
test_df.map(str.lower)
# Out:
#        Country Employment_Status
# 916   pakistan          employed
# 1198  pakistan           student
# 1390  pakistan          employed
# 2917  pakistan          employed
# 3044  pakistan          employed
# 3509  pakistan          employed
# 3553  pakistan          employed
# 3585  pakistan           student
# 3598  pakistan          employed
# 3694  pakistan          employed

# %%
test_df.reset_index(inplace=True)
test_df.loc[[0, 5, 8], "Employment_Status"] = "Unemployed"
test_df["Finding_Job"] = test_df["Employment_Status"].map(
    {"Employed": False, "Student": False, "Unemployed": True}
)
test_df
# Out:
#    index   Country Employment_Status  Finding_Job
# 0    916  Pakistan        Unemployed         True
# 1   1198  Pakistan           Student        False
# 2   1390  Pakistan          Employed        False
# 3   2917  Pakistan          Employed        False
# 4   3044  Pakistan          Employed        False
# 5   3509  Pakistan        Unemployed         True
# 6   3553  Pakistan          Employed        False
# 7   3585  Pakistan           Student        False
# 8   3598  Pakistan        Unemployed         True
# 9   3694  Pakistan          Employed        False

# %%
type(new_test_df)
# Out:
# pandas.core.series.Series

# %%
df

# %%
print(len(new_test_df))
print(len(df))
# Out:
# 70975
# 73268

# %%
df['LanguageHaveWorkedWith'].str.split(';',expand=True)
new_test_df=df.loc[df['LanguageHaveWorkedWith'].notna(),'LanguageHaveWorkedWith']
new_test_df=(new_test_df.str.split(';')).apply(len)
# new_test_df=new_test_df.apply(len)
# new_test_df.reset_index(inplace=True)
len(df['LanguageHaveWorkedWith'].loc[new_test_df.idxmax()].split(";"))
# Out:
# 42

# %%
test_df.drop(columns=['Employment_Status'])
# Out:
#    index   Country  Finding_Job
# 0    916  Pakistan         True
# 1   1198  Pakistan        False
# 2   1390  Pakistan        False
# 3   2917  Pakistan        False
# 4   3044  Pakistan        False
# 5   3509  Pakistan         True
# 6   3553  Pakistan        False
# 7   3585  Pakistan        False
# 8   3598  Pakistan         True
# 9   3694  Pakistan        False

# %%
import numpy
new_df = pd.DataFrame(
    {
        "Country": ["India", "NA", "India", "China"],
        "Employment_Status": ["Employed", numpy.nan, "Employed", numpy.nan],
        "Finding_Job": ["NA", False, False, None],
    }
)
new_df
# Out:
#   Country Employment_Status Finding_Job
# 0   India          Employed          NA
# 1      NA               NaN       False
# 2   India          Employed       False
# 3   China               NaN        None

# %%
# result = pd.concat([test_df, new_df], axis=0, keys=['test_df', 'new_df'])
# print(result)
# print(test_df)
# test_df.reset_index(drop=True)

new_df2=pd.concat([test_df,new_df],ignore_index=False)
  
new_df2


# new_df3=pd.Series(['Yes','Yes','No','No'],name='Willing_To_Relocate')
# # new_df3=new_df3.to_frame(name=)
# print(pd.concat([new_df,new_df3],axis=1))
# Out:
#        Country                                         Employment  \
# 916   Pakistan                                Employed, full-time
# 1198  Pakistan                                 Student, full-time
# 1390  Pakistan                                Employed, full-time
# 2917  Pakistan                                Employed, full-time
# 3044  Pakistan                                Employed, full-time
# 3509  Pakistan  Employed, full-time;Independent contractor, fr...
# 3553  Pakistan                                Employed, full-time
# 3585  Pakistan  Student, part-time;Independent contractor, fre...
# 3598  Pakistan                                Employed, full-time
# 3694  Pakistan                                Employed, full-time
# 0        India                                                NaN
# 1       Moroco                                                NaN
# 2        India                                                NaN
# ...

# %%
# new_df2.drop(index=new_df2[new_df2['Country']=='India'].index)
# Out:
#      Country Employment_Status  Finding_Job
# 0   Pakistan        Unemployed         True
# 1   Pakistan           Student        False
# 2   Pakistan          Employed        False
# 3   Pakistan          Employed        False
# 4   Pakistan          Employed        False
# 5   Pakistan        Unemployed         True
# 6   Pakistan          Employed        False
# 7   Pakistan           Student        False
# 8   Pakistan        Unemployed         True
# 9   Pakistan          Employed        False
# 11    Moroco           Student        False
# 13     China        Unemployed         True

# %%
new_df2.sort_values(by=['Country','Employment_Status'],ascending=True)
# Out:
#        Country                                         Employment  \
# 3        China                                                NaN
# 0        India                                                NaN
# 2        India                                                NaN
# 1       Moroco                                                NaN
# 916   Pakistan                                Employed, full-time
# 1198  Pakistan                                 Student, full-time
# 1390  Pakistan                                Employed, full-time
# 2917  Pakistan                                Employed, full-time
# 3044  Pakistan                                Employed, full-time
# 3509  Pakistan  Employed, full-time;Independent contractor, fr...
# 3553  Pakistan                                Employed, full-time
# 3585  Pakistan  Student, part-time;Independent contractor, fre...
# 3598  Pakistan                                Employed, full-time
# ...

# %%
new_df2.sort_index()
# Out:
#      Country Employment_Status  Finding_Job
# 0   Pakistan        Unemployed         True
# 1   Pakistan           Student        False
# 2   Pakistan          Employed        False
# 3   Pakistan          Employed        False
# 4   Pakistan          Employed        False
# 5   Pakistan        Unemployed         True
# 6   Pakistan          Employed        False
# 7   Pakistan           Student        False
# 8   Pakistan        Unemployed         True
# 9   Pakistan          Employed        False
# 10     India          Employed        False
# 11    Moroco           Student        False
# 12     India          Employed        False
# 13     China        Unemployed         True

# %%
df.nlargest(columns=['ConvertedCompYearly'],n=10)
# Out:
#        index                                            Country  ResponseId  \
# 40304  40304  United Kingdom of Great Britain and Northern I...       40305
# 201      201                                           Portugal         202
# 62026  62026                           United States of America       62027
# 70522  70522                           United States of America       70523
# 61043  61043                                           Thailand       61044
# 18922  18922                           United States of America       18923
# 62223  62223                           United States of America       62224
# 66495  66495                           United States of America       66496
# 1290    1290                           United States of America        1291
# 24163  24163                           United States of America       24164
#
#                            MainBranch  \
# 40304  I am a developer by profession
# 201    I am a developer by profession
# ...

# %%
df.nsmallest(columns=['ConvertedCompYearly'],n=10)
# Out:
#        index                   Country  ResponseId  \
# 19912  19912                   Belgium       19913
# 39915  39915                     India       39916
# 52005  52005                  Viet Nam       52006
# 64366  64366  United States of America       64367
# 65742  65742                     India       65743
# 6123    6123               South Korea        6124
# 32332  32332                  Viet Nam       32333
# 36435  36435                     Japan       36436
# 2376    2376                  Colombia        2377
# 27980  27980                     Japan       27981
#
#                                               MainBranch  \
# 19912  I am not primarily a developer, but I write co...
# 39915                     I am a developer by profession
# 52005                     I am a developer by profession
# 64366  I am not primarily a developer, but I write co...
# 65742                     I am a developer by profession
# ...

# %%
df.median(numeric_only=True)
# Out:
# index                        36633.5
# ResponseId                   36634.5
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df.describe()
# Out:
#               index    ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  73268.000000  3.842200e+04                    0.0
# mean   36633.500000  36634.500000  2.342434e+52                    NaN
# std    21150.794099  21150.794099  4.591478e+54                    NaN
# min        0.000000      1.000000  0.000000e+00                    NaN
# 25%    18316.750000  18317.750000  3.000000e+04                    NaN
# 50%    36633.500000  36634.500000  7.750000e+04                    NaN
# 75%    54950.250000  54951.250000  1.540000e+05                    NaN
# max    73267.000000  73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# ...

# %%
df['CompTotal'].count()
# Out:
# np.int64(38422)

# %%
schema_df.index
schema_df.loc['MetaInfo','question']
df['MentalHealth']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2        I have a mood or emotional disorder (e.g., dep...
# 3                                        None of the above
# 4                                                      NaN
#                                ...
# 73263                                    None of the above
# 73264                                    None of the above
# 73265                                    None of the above
# 73266                                    None of the above
# 73267                                    None of the above
# Name: MentalHealth, Length: 73268, dtype: object

# %%
df['Country'].value_counts(normalize=True)
# Out:
# Country
# United States of America                                0.188697
# India                                                   0.092503
# Germany                                                 0.075170
# United Kingdom of Great Britain and Northern Ireland    0.058380
# Canada                                                  0.034694
#                                                           ...
# Monaco                                                  0.000014
# Djibouti                                                0.000014
# Seychelles                                              0.000014
# Solomon Islands                                         0.000014
# Saint Kitts and Nevis                                   0.000014
# Name: proportion, Length: 180, dtype: float64

# %%
country_grp = df.groupby(by=['Country']) 
print(country_grp)

# %%
country_grp.get_group(name=('Pakistan'))
# Out:
# /tmp/ipykernel_6615/4151409613.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group(name=('Pakistan'))
#        index   Country  ResponseId                      MainBranch  \
# 916      916  Pakistan         917  I am a developer by profession
# 1198    1198  Pakistan        1199           I am learning to code
# 1390    1390  Pakistan        1391  I am a developer by profession
# 2917    2917  Pakistan        2918  I am a developer by profession
# 3044    3044  Pakistan        3045  I am a developer by profession
# ...      ...       ...         ...                             ...
# 72824  72824  Pakistan       72825  I am a developer by profession
# 72868  72868  Pakistan       72869  I am a developer by profession
# 72908  72908  Pakistan       72909  I am a developer by profession
# ...

# %%
country_grp['Employment'].get_group(name=('Pakistan',)).value_counts(normalize=True).head(30)
# Out:
# Employment
# Employed, full-time                                                                                            0.514085
# Independent contractor, freelancer, or self-employed                                                           0.088732
# Student, full-time                                                                                             0.081690
# Employed, full-time;Independent contractor, freelancer, or self-employed                                       0.074648
# Not employed, but looking for work                                                                             0.036620
# Student, part-time                                                                                             0.029577
# Employed, part-time                                                                                            0.022535
# Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time                   0.021127
# ...

# %%
country_grp['ConvertedCompYearly'].median().loc[['Pakistan','Germany','India','China']]
country_grp['ConvertedCompYearly']
# Out:
# Country
# Pakistan     7476.0
# Germany     69318.0
# India       18576.0
# China       45048.0
# Name: ConvertedCompYearly, dtype: float64

# %%
country_grp['ConvertedCompYearly'].agg(func=['median','mean']).loc[['Pakistan','Germany','India','China']]
# Out:
#            median           mean
# Country
# Pakistan   7476.0   16691.010345
# Germany   69318.0  115087.296703
# India     18576.0   51443.079613
# China     45048.0   65380.908537

# %%
numeric_cols=df.select_dtypes(include=['int64','float64',])
# numeric_cols.dropna(inplace=True)
numeric_cols.drop(["VCHostingPersonal use","VCHostingProfessional use"],axis=1,inplace = True)
print(len(numeric_cols))
numeric_cols.dropna(inplace=True)
print(len(numeric_cols))

numeric_cols.agg(func=['median','mean'])
# Out:
# 73268
# 27103
#           ResponseId     CompTotal    WorkExp  ConvertedCompYearly
# median  38095.000000  8.000000e+04   8.000000         65435.000000
# mean    36837.561377  2.908907e+06  10.436557        160069.094344

# %% [markdown]
# This is Code For finding percentage of people from each country who knew python
# Finding country with maximum python developers
# And Table showing total count of developers in a country and how many of them knows python

# %%
total=country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python')).sum()
result=country_grp['LanguageHaveWorkedWith'].apply(lambda x: ((x.str.contains('Python').sum())/total)*100)
print(result)
print(result.idxmax())
print(result.max())
df_to_combine1=df['Country'].value_counts()
df_to_combine2=country_grp['LanguageHaveWorkedWith'].apply(lambda x: ((x.str.contains('Python').sum())))
print(7017/total)
pd.concat([df_to_combine1,df_to_combine2],axis=1).sort_values(by=['LanguageHaveWorkedWith'],ascending=False)
# Out:
# Country
# Afghanistan                             0.073196
# Albania                                 0.055629
# Algeria                                 0.055629
# Andorra                                 0.011711
# Angola                                  0.008783
#                                           ...
# Venezuela, Bolivarian Republic of...    0.152247
# Viet Nam                                0.398185
# Yemen                                   0.011711
# Zambia                                  0.017567
# Zimbabwe                                0.032206
# Name: LanguageHaveWorkedWith, Length: 180, dtype: float64
# United States of America
# 20.54457619675011
# 0.2054457619675011
#                                                     count  \
# Country
# United States of America                            13543
# India                                                6639
# Germany                                              5395
# ...

# %%
print(new_df)
new_df.dropna(axis=0, how='all', subset=['Country','Employment_Status'])
# Out:
#   Country Employment_Status Finding_Job
# 0   India          Employed          NA
# 1      NA               NaN       False
# 2   India          Employed       False
# 3   China               NaN        None
#   Country Employment_Status Finding_Job
# 0   India          Employed          NA
# 1      NA               NaN       False
# 2   India          Employed       False
# 3   China               NaN        None

# %%
new_df.isna()
# Out:
#    Country  Employment_Status  Finding_Job
# 0    False              False        False
# 1    False               True        False
# 2    False              False        False
# 3    False               True         True

# %%
new_df.fillna(0)
# Out:
#   Country Employment_Status Finding_Job
# 0   India          Employed          NA
# 1      NA                 0       False
# 2   India          Employed       False
# 3   China                 0           0

# %%
new_df.dtypes
# Out:
# Country              object
# Employment_Status    object
# Finding_Job          object
# dtype: object

# %%
schema_df.loc['YearsCode','question']
# Out:
#   Cell In[20], line 1
#     schema_df.loc['YearsCode','question']b
#                                          ^
# SyntaxError: invalid syntax

# %%
df['YearsCode']=df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df['YearsCode']=df['YearsCode'].astype(float)
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, 14., 20.,  8., 15.,  3.,  1.,  6., 37.,  5., 12., 22., 11.,
#         4.,  7., 13., 36.,  2., 25., 10., 40., 16., 27., 24., 19.,  9.,
#        17., 18., 26., 51., 29., 30., 32.,  0., 48., 45., 38., 39., 28.,
#        23., 43., 21., 41., 35., 50., 33., 31., 34., 46., 44., 42., 47.,
#        49.])

# %%
df['YearsCode'].replace({'Less than 1 year':0,'More than 50 years':51}, inplace=True)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df.dropna(axis=0,how='any',subset=['ConvertedCompYearly']).groupby(by=['YearsCode','Country']).apply(lambda tdf:tdf.loc[tdf['ConvertedCompYearly'].idxmax(skipna=True)])
# Out:
# /tmp/ipykernel_4688/3130206380.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.dropna(axis=0,how='any',subset=['ConvertedCompYearly']).groupby(by=['YearsCode','Country']).apply(lambda tdf:tdf.loc[tdf['ConvertedCompYearly'].idxmax(skipna=True)])
#                                                               ResponseId  \
# YearsCode Country
# 0.0       Argentina                                                44995
#           Austria                                                  16858
#           Azerbaijan                                               54342
#           Bangladesh                                               56017
# ...

# %%
import numpy as np

s = pd.DataFrame({'col1':np.random.randint(0,100,10000),'col2':np.random.randint(0,100,10000)})
s.head()
s.plot.hexbin(x='col1',y='col2',gridsize=15)
# s.plot.kde()
# s.plot.hist()
# s.plot.line()
# s.plot.bar()
# s.plot.area()
# Out:
# <Axes: xlabel='col1', ylabel='col2'>
